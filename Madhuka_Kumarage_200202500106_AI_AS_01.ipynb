# %% [markdown]
# # **<u>Health Lifestyle Analysis</u>**

# %%
import pandas as pd

# %% [markdown]
# ## Dataset
#
# ##### Dataset Title :
# Synthetic Health and Lifestyle Dataset
#
# ##### Dataset Description :
# This is a synthetic dataset generated to simulate health and lifestyle information for 1,326 individuals. It includes key attributes such as age, gender, body meeasurments (Height, Weight), Lifestyle habits (Smoking, Alchohol consumption, Excersise Frequency), sleep pattern, and presece of chronic diseases.
#
# [Full Dataset on Kaggle](https://www.kaggle.com/datasets/sahilislam007/health-and-lifestyle-dataset)

# %%
df = pd.read_csv('./datasets/synthetic_health_lifestyle_dataset.csv')
df.drop(["Height_cm","Weight_kg"],axis="columns",inplace=True)
df.head()
# Out:
#    ID  Age  Gender   BMI Smoker   Exercise_Freq Diet_Quality  \
# 0   1   56   Other  11.8    Yes             NaN         Poor
# 1   2   69   Other  24.7     No  1-2 times/week         Good
# 2   3   46  Female  27.3     No           Daily    Excellent
# 3   4   32    Male  26.3     No  3-5 times/week    Excellent
# 4   5   60    Male  24.1     No  3-5 times/week    Excellent
#
#   Alcohol_Consumption Chronic_Disease  Stress_Level  Sleep_Hours
# 0                 NaN              No             9          8.5
# 1                High              No             2          5.9
# 2            Moderate              No             3          4.8
# 3            Moderate              No             9          6.6
# 4                 Low             Yes             6          6.1

# %% [markdown]
# #### Handling Missing Values
#
# ##### Columns :
# + Excercise_Freq
# + Alcohol_Consumption

# %%
df["Exercise_Freq"] = df["Exercise_Freq"].fillna(df["Exercise_Freq"].mode()[0])
df["Alcohol_Consumption"] = df["Alcohol_Consumption"].fillna(df["Alcohol_Consumption"].mode()[0])
df.isna().sum()
# Out:
# ID                     0
# Age                    0
# Gender                 0
# BMI                    0
# Smoker                 0
# Exercise_Freq          0
# Diet_Quality           0
# Alcohol_Consumption    0
# Chronic_Disease        0
# Stress_Level           0
# Sleep_Hours            0
# dtype: int64

# %% [markdown]
# #### Encording Categorical Variables

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
binaryMap = {"Yes":1,"No":0}

# %% [markdown]
# ---
# **Use "_Label Encording_" technique** <br><br>
# Columns :
# + Gender
# + Exercise_Freq
# + Diet_Quality
# + Alcohol_Consumption

# %%
df["Gender"] = le.fit_transform(df["Gender"])
df["Exercise_Freq"] = le.fit_transform(df["Exercise_Freq"])
df["Diet_Quality"] = le.fit_transform(df["Diet_Quality"])
df["Alcohol_Consumption"] = le.fit_transform(df["Alcohol_Consumption"])
df.head()
# Out:
#    ID  Age  Gender   BMI Smoker  Exercise_Freq  Diet_Quality  \
# 0   1   56       2  11.8    Yes              2             3
# 1   2   69       2  24.7     No              0             2
# 2   3   46       0  27.3     No              2             1
# 3   4   32       1  26.3     No              1             1
# 4   5   60       1  24.1     No              1             1
#
#    Alcohol_Consumption Chronic_Disease  Stress_Level  Sleep_Hours
# 0                    1              No             9          8.5
# 1                    0              No             2          5.9
# 2                    2              No             3          4.8
# 3                    2              No             9          6.6
# 4                    1             Yes             6          6.1

# %% [markdown]
# ---
# **Use "_Binary Encording_" technique**
# <br>
# <br>
# Columns :
# + Smoker
# + Chronic_Diesease

# %%
df["Smoker"] = df["Smoker"].map(binaryMap)
df["Chronic_Disease"] = df["Chronic_Disease"].map(binaryMap)
df.head()
# Out:
#    ID  Age  Gender   BMI  Smoker  Exercise_Freq  Diet_Quality  \
# 0   1   56       2  11.8       1              2             3
# 1   2   69       2  24.7       0              0             2
# 2   3   46       0  27.3       0              2             1
# 3   4   32       1  26.3       0              1             1
# 4   5   60       1  24.1       0              1             1
#
#    Alcohol_Consumption  Chronic_Disease  Stress_Level  Sleep_Hours
# 0                    1                0             9          8.5
# 1                    0                0             2          5.9
# 2                    2                0             3          4.8
# 3                    2                0             9          6.6
# 4                    1                1             6          6.1

# %%
from sklearn.preprocessing import Normalizer

nz = Normalizer()

y_values = df["Chronic_Disease"]
x_values = df.drop(columns="Chronic_Disease")

normalized = nz.fit_transform(x_values)
normalized_df = pd.DataFrame(normalized,columns=x_values.columns)

normalized_df.drop("ID",axis="columns",inplace=True)
normalized_df.head()
# Out:
#         Age    Gender       BMI    Smoker  Exercise_Freq  Diet_Quality  \
# 0  0.953616  0.034058  0.200941  0.017029       0.034058      0.051087
# 1  0.937073  0.027162  0.335445  0.000000       0.000000      0.027162
# 2  0.852535  0.000000  0.505961  0.000000       0.037067      0.018533
# 3  0.741335  0.023167  0.609285  0.000000       0.023167      0.023167
# 4  0.916803  0.015280  0.368249  0.000000       0.015280      0.015280
#
#    Alcohol_Consumption  Stress_Level  Sleep_Hours
# 0             0.017029      0.153260     0.144745
# 1             0.000000      0.027162     0.080127
# 2             0.037067      0.055600     0.088960
# 3             0.046333      0.208500     0.152900
# 4             0.015280      0.091680     0.093208

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_values,y_values,test_size=0.2)

# %% [markdown]
# ---
#
# ### Support Vector Machine

# %%
from sklearn.svm import SVC

# %%
model_lin = SVC(kernel="linear")
model_lin.fit(x_train,y_train)
model_lin.score(x_test,y_test)

# %%
model_rbf = SVC(kernel="rbf")
model_rbf.fit(x_train,y_train)
model_rbf.score(x_test,y_test)

# %%
model_poly = SVC(kernel="poly")
model_poly.fit(x_train,y_train)
model_poly.score(x_test,y_test)

# %% [markdown]
# ---
#
# ### Gaussian Naïve Bayes

# %%
from sklearn.naive_bayes import GaussianNB
model= GaussianNB()
model.fit(x_train,y_train)
model.score(x_test,y_test)
